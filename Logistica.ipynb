# %% [markdown]
# <a href="https://colab.research.google.com/github/JosePabloGFnl/CEMEX-Hacks-2022/blob/main/Logistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib notebook

#csv para las coordenadas de los centros de distribución
coord = pd.read_csv('coord.csv', index_col=0, encoding='latin-1')

# %%
#para mostrar el dataframe
coord = coord.reset_index()
coord
# Out:
#      x   y  Valor de costo  Valor de ubicación  Valor de clima
# 0   60  50              80                 100              90
# 1   60  50              80                 100              90
# 2   60  45              70                  80              80
# 3   50  75              75                  80              75
# 4   40  30              60                  70              70
# 5   30  50              50                  60              70
# 6   60  50              80                 100              90
# 7   30  50              50                  60              70
# 8   20  30              60                  30              65
# 9   40  30              60                  70              70
# 10  60  45              70                  80              80
# 11  50  75              75                  80              75

# %%
#promedio de x & y para tener un punto inicial
initx = round(coord["x"].mean())
inity = round(coord["y"].mean())

# %%
#convertirlo a valores floar para que se haga bien la operación
coord['x'] = coord['x'].astype(float)
coord['y'] = coord['y'].astype(float)
initx = float(initx)
inity = float(inity)

# %%
initx
# Out:
# 47.0

# %%
inity
# Out:
# 48.0

# %%
#función para operación matemática
def distancia(value):
  round(math.sqrt((initx - value['x']) ** 2 + (inity - value['y']) ** 2))

# %%
#distancias entre los promedios de x & y
distancia=[]  
distancia1=[]  
distancia2=[] 
distancia3=[] 
s=[]

for i in coord["x"]:
    dist=(initx - i) ** 2
    distancia.append(dist)
    
for p in coord["y"]:
    dist1=(initx - p) ** 2
    distancia1.append(dist1)
    
def sumaListas(a,b):
    for i in range(len(a)):
        s.append(a[i]+b[i])
    return s

distancia3=sumaListas(distancia,distancia1)

for u in distancia3: 
    dist_sqrt= math.sqrt(u)
    distancia2.append(dist_sqrt)
    
coord["dist"]=distancia2



coord
# Out:
#        x     y  Valor de costo  Valor de ubicación  Valor de clima       dist
# 0   60.0  50.0              80                 100              90  13.341664
# 1   60.0  50.0              80                 100              90  13.341664
# 2   60.0  45.0              70                  80              80  13.152946
# 3   50.0  75.0              75                  80              75  28.160256
# 4   40.0  30.0              60                  70              70  18.384776
# 5   30.0  50.0              50                  60              70  17.262677
# 6   60.0  50.0              80                 100              90  13.341664
# 7   30.0  50.0              50                  60              70  17.262677
# 8   20.0  30.0              60                  30              65  31.906112
# 9   40.0  30.0              60                  70              70  18.384776
# 10  60.0  45.0              70                  80              80  13.152946
# 11  50.0  75.0              75                  80              75  28.160256

# %%
coord["Valor Total"] = coord["Valor de costo"] + coord["Valor de ubicación"] + coord["Valor de clima"] + coord["dist"]

# %%
coord
# Out:
#        x     y  Valor de costo  Valor de ubicación  Valor de clima       dist  \
# 0   60.0  50.0              80                 100              90  13.341664
# 1   60.0  50.0              80                 100              90  13.341664
# 2   60.0  45.0              70                  80              80  13.152946
# 3   50.0  75.0              75                  80              75  28.160256
# 4   40.0  30.0              60                  70              70  18.384776
# 5   30.0  50.0              50                  60              70  17.262677
# 6   60.0  50.0              80                 100              90  13.341664
# 7   30.0  50.0              50                  60              70  17.262677
# 8   20.0  30.0              60                  30              65  31.906112
# 9   40.0  30.0              60                  70              70  18.384776
# 10  60.0  45.0              70                  80              80  13.152946
# 11  50.0  75.0              75                  80              75  28.160256
#
#     Valor Total
# 0    283.341664
# 1    283.341664
# 2    243.152946
# 3    258.160256
# 4    218.384776
# 5    197.262677
# 6    283.341664
# 7    197.262677
# 8    186.906112
# 9    218.384776
# 10   243.152946
# 11   258.160256

# %%
coord = coord.sort_values('Valor Total', ascending=False)
coord = coord.drop_duplicates()
coord
# Out:
#       x     y  Valor de costo  Valor de ubicación  Valor de clima       dist  \
# 0  60.0  50.0              80                 100              90  13.341664
# 3  50.0  75.0              75                  80              75  28.160256
# 2  60.0  45.0              70                  80              80  13.152946
# 4  40.0  30.0              60                  70              70  18.384776
# 5  30.0  50.0              50                  60              70  17.262677
# 8  20.0  30.0              60                  30              65  31.906112
#
#    Valor Total
# 0   283.341664
# 3   258.160256
# 2   243.152946
# 4   218.384776
# 5   197.262677
# 8   186.906112

# %%
initx = round(coord["x"].mean())
inity = round(coord["y"].mean())

distancia=[]  
distancia1=[]  
distancia2=[] 
distancia3=[] 
s=[]

for i in coord["x"]:
    dist=(initx - i) ** 2
    distancia.append(dist)
    
for p in coord["y"]:
    dist1=(initx - p) ** 2
    distancia1.append(dist1)

distancia3=sumaListas(distancia,distancia1)

for u in distancia3: 
    dist_sqrt= math.sqrt(u)
    distancia2.append(dist_sqrt)
    
coord["dist"]=distancia2

coord
# Out:
#       x     y  Valor de costo  Valor de ubicación  Valor de clima       dist  \
# 0  60.0  50.0              80                 100              90  18.384776
# 3  50.0  75.0              75                  80              75  32.756679
# 2  60.0  45.0              70                  80              80  17.117243
# 4  40.0  30.0              60                  70              70  13.341664
# 5  30.0  50.0              50                  60              70  14.764823
# 8  20.0  30.0              60                  30              65  26.419690
#
#    Valor Total
# 0   283.341664
# 3   258.160256
# 2   243.152946
# 4   218.384776
# 5   197.262677
# 8   186.906112

# %%
coord = coord.reset_index()

# %%
#Promedio de la distancia final
index = coord.index
number_of_rows = len(index)

percen = round(number_of_rows / 4)

# %%
number_of_rows
# Out:
# 6

# %%
percen
# Out:
# 2

# %%
coord = coord.iloc[0:percen]

final = round(coord["dist"].mean())
final
# Out:
# 26

# %%
print("El mejor punto para ubicación de un centro de distribución es de " + str(final) + " puntos de unidad de distancia con las coordenadas X: " + str(initx) +" Y: " + str(inity))
# Out:
# El mejor punto para ubicación de un centro de distribución es de 26 puntos de unidad de distancia con las coordenadas X: 43 Y: 47
